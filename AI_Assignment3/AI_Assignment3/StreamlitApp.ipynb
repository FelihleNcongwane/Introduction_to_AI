# %%
# !pip install streamlit -q

# %%
# !wget q -O - ipv4.icanhazip.com
# Out:
# --2023-11-17 22:35:11--  http://q/
# Resolving q (q)... failed: Name or service not known.
# wget: unable to resolve host address ‘q’
# --2023-11-17 22:35:11--  http://ipv4.icanhazip.com/
# Resolving ipv4.icanhazip.com (ipv4.icanhazip.com)... 104.18.114.97, 104.18.115.97
# Connecting to ipv4.icanhazip.com (ipv4.icanhazip.com)|104.18.114.97|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13 [text/plain]
# Saving to: ‘STDOUT’
#
# -                     0%[                    ]       0  --.-KB/s               34.23.215.52
# -                   100%[===================>]      13  --.-KB/s    in 0s
#
# 2023-11-17 22:35:11 (2.18 MB/s) - written to stdout [13/13]
#
# FINISHED --2023-11-17 22:35:11--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 13 in 0s (2.18 MB/s)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.23.215.52:8501
#
# npx: installed 22 in 4.243s
# your url is: https://warm-dots-raise.loca.lt
# 2023-11-17 22:36:10.790801: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-17 22:36:10.790859: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-17 22:36:10.790892: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-17 22:36:12.212973: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
